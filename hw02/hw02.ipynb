# %%
import os

import torch 
from torch_geometric.datasets import Planetoid
from torch_geometric.utils import to_scipy_sparse_matrix
import pandas as pd
import networkx as nx
import numpy as np

# %%
# Declare all hyperparameters
DROPOUT_RATE=0.1
LEARNING_RATE=0.01
WEIGHT_DECAY=4e-5
BATCH_SIZE=256
RANDOM_SEED=42
NUM_EPOCHS=10
NEGATIVE_EDGES=2
THRESHOLD_POSITIVE=0.5

# %%
def load_cora(path="data/cora"):
    content=pd.read_csv(f"{path}/cora.content", sep="\t", header=None)
    cites=pd.read_csv(f"{path}/cora.cites", sep="\t", header=None)

    return content, cites

# %%
def graph_construction(content, cites):
    
    paper_id=content.iloc[:, 0]
    word_attributes=content.iloc[:, 1:-1]
    class_label=content.iloc[:, -1]

    G=nx.Graph()

    # Add nodes with attributes
    # for i in range(len(paper_id)):
    #     G.add_node(paper_id[i], word_attributes=word_attributes.iloc[i].values, class_label=class_label[i])
    node_attrs = {
        paper_id[i]: {
            'word_attributes': word_attributes.iloc[i].values, 
            'class_label': class_label[i]
        } for i in range(len(paper_id))
    }
    
    # Add nodes with attributes in one line
    G.add_nodes_from(node_attrs.items())
    
    edges_numpy = [(np.int64(src), np.int64(dst)) for src, dst in cites.values]
    # Add edges
    G.add_edges_from(edges_numpy)
    
    return G

# %%
class GraphConv():

# %%
def main():
    content, cites = load_cora()
    G=graph_construction(content, cites)
    print("G nodes: ", G.nodes())
    print("G edges: ", G.edges())
    print("G node's attributes: ", G.nodes(data=True))

# %%
if __name__ == "__main__":
    main()
# Out:
# G nodes:  [np.int64(31336), np.int64(1061127), np.int64(1106406), np.int64(13195), np.int64(37879), np.int64(1126012), np.int64(1107140), np.int64(1102850), np.int64(31349), np.int64(1106418), np.int64(1123188), np.int64(1128990), np.int64(109323), np.int64(217139), np.int64(31353), np.int64(32083), np.int64(1126029), np.int64(1118017), np.int64(49482), np.int64(753265), np.int64(249858), np.int64(1113739), np.int64(48766), np.int64(646195), np.int64(1126050), np.int64(59626), np.int64(340299), np.int64(354004), np.int64(242637), np.int64(1106492), np.int64(74975), np.int64(1152272), np.int64(100701), np.int64(66982), np.int64(13960), np.int64(13966), np.int64(66990), np.int64(182093), np.int64(182094), np.int64(13972), np.int64(13982), np.int64(16819), np.int64(273152), np.int64(237521), np.int64(1153703), np.int64(32872), np.int64(284025), np.int64(218666), np.int64(16843), np.int64(1153724), np.int64(1153728), np.int64(158098), np.int64(8699), np.int64(1134865), np.int64(28456), n
# ...
